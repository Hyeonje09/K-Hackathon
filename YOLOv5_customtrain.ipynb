# %% [markdown]
# <a href="https://colab.research.google.com/github/Hyeonje09/K-Hackathon/blob/deep/YOLOv5_customtrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
# !curl -L "https://universe.roboflow.com/ds/byR6rKQ9jV?key=3neBnf0R7O" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: train/labels/8_mp4-144_jpg.rf.7e619a7fed911bda45f52711008af287.txt
#  extracting: train/labels/8_mp4-145_jpg.rf.f9afa9716d8be0e83de2fed26a0eab59.txt
#  extracting: train/labels/8_mp4-146_jpg.rf.aec9aa4633d5647fcde2e9fb06120fbb.txt
#  extracting: train/labels/8_mp4-147_jpg.rf.1075638805c456d53d3a9a7eda56fce5.txt
#  extracting: train/labels/8_mp4-148_jpg.rf.d101cf2b96414ff8606eb74a74686fe0.txt
#  extracting: train/labels/8_mp4-149_jpg.rf.924513fc9f60c9def5e8fc038f3714fb.txt
#  extracting: train/labels/8_mp4-14_jpg.rf.86ba4e06880318c768494ee44cce8a7b.txt
#  extracting: train/labels/8_mp4-151_jpg.rf.e349ee87f509c95ee5f3bb35a41331df.txt
#  extracting: train/labels/8_mp4-156_jpg.rf.90a73eb058d1ce198bf8d7115e3f2aa4.txt
#  extracting: train/labels/8_mp4-157_jpg.rf.4b05982f68cefa0747e4f0b69970595d.txt
#  extracting: train/labels/8_mp4-158_jpg.rf.4bd7fb2f6d01f774a898bf60b850b90a.txt
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15916, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 15916 (delta 13), reused 26 (delta 9), pack-reused 15880
# Receiving objects: 100% (15916/15916), 14.66 MiB | 18.00 MiB/s, done.
# Resolving deltas: 100% (10908/10908), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.7/616.7 kB 39.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.4 MB/s eta 0:00:00
# ...

# %%
# !python train.py --img 640 --batch 8 --epochs 100 --data /content/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name capture_yolov5s_results
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/content/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=capture_yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-209-g493981c Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --weights ./runs/train/capture_yolov5s_results/weights/best.pt --conf 0.5 --source /can.jpg
# Out:
# detect: weights=['./runs/train/capture_yolov5s_results/weights/best.pt'], source=/can.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-209-g493981c Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /can.jpg: 640x640 1 can, 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2
